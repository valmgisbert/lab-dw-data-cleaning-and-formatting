# %% [markdown]
# # Lab | Data Cleaning and Formatting

# %% [markdown]
# Objective: Apply Python programming to perform data cleaning and formatting, including identifying and handling with missing values, duplicates, outliers, errors, and using various formatting techniques such as changing data types, renaming columns, and handling string values, to prepare data for analysis.

# %% [markdown]
# In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv

# %% [markdown]
# # Challenge 1: Data Cleaning and Formatting

# %% [markdown]
# ## Exercise 1: Cleaning Column Names

# %% [markdown]
# To ensure consistency and ease of use, standardize the column names of the dataframe. Start by taking a first look at the dataframe and identifying any column names that need to be modified. Use appropriate naming conventions and make sure that column names are descriptive and informative.

# %%
import pandas as pd
import numpy as np

customer = pd.read_csv('customer.csv')
customer
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
customer.columns = customer.columns.str.lower().str.replace(' ','_') #turn all to lowercase and replace spaces with _s
customer.rename(columns={'st': 'state'}, inplace=True)  #rename column(s) and make sure the changes are applied in the df
customer
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      number_of_open_complaints     policy_type  vehicle_class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       total_claim_amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %% [markdown]
# ## Exercise 2: Cleaning invalid Values

# %% [markdown]
# The dataset contains columns with inconsistent and incorrect values that could affect the accuracy of our analysis. Therefore, we need to clean these columns to ensure that they contain only valid data. For example, the gender column contains various inconsistent values such as "F", "M", "Femal", "Male", "female", which need to be standardized.
#
# Note that this exercise will focus only on cleaning inconsistent values and will not involve handling null values (NaN or None).

# %%
customer.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
customer['state'].value_counts()
# Out:
# Oregon        320
# California    211
# Arizona       186
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: state, dtype: int64

# %%
def clean_state(x):
    if x in ['Cali']:
        return 'California'
    elif x in ['WA'] :
        return 'Washington'
    elif x in ['AZ']:
        return 'Arizona'
    else:
        return x
    
customer['state'] = list(map(clean_state, customer['state']))
customer['state'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', nan],
#       dtype=object)

# %%
customer['gender'].value_counts()
# Out:
# F         457
# M         413
# Male       39
# female     28
# Femal      17
# Name: gender, dtype: int64

# %%
# customer['gender'].unique()
#'F', 'M', 'Femal', 'Male', 'female'

#not able to use .startswith() bc rn with the nans its a float
def clean_gender(x):
    if x in ['M', 'Male']:
        return 'M'
    elif x in ['F','Femal','female'] :
        return 'F'
    
customer['gender'] = list(map(clean_gender ,customer['gender']))
customer['gender'].unique()
# Out:
# array([None, 'F', 'M'], dtype=object)

# %% [markdown]
# ## Exercise 3: Formatting data types

# %% [markdown]
# The data types of many columns in the dataset appear to be incorrect. This could impact the accuracy of our analysis. To ensure accurate analysis, we need to correct the data types of these columns. Please update the data types of the columns as appropriate.

# %% [markdown]
# It is important to note that this exercise does not involve handling null values (NaN or None).

# %%
customer['customer_lifetime_value'] = customer['customer_lifetime_value'].str.rstrip('%').astype('float') / 100.0 
#making customer obj into a float by deleting % and making it a float

# %%
customer['number_of_open_complaints'] = customer['number_of_open_complaints'].str.split('/',n=2, expand=True)[1]

# %% [markdown]
# ## Exercise 4: Dealing with Null values

# %% [markdown]
# Identify any columns with null or missing values. Identify how many null values each column has. You can use the isnull() function in pandas to find columns with null values.
#
# Decide on a strategy for handling the null values. There are several options, including:
#
# - Drop the rows or columns with null values
# - Fill the null values with a specific value (such as the column mean or median for numerical variables and mode for categorical variables)
# - Fill the null values with the previous or next value in the column
# - Fill the null values based on a more complex algorithm or model (we haven't studied this yet)
#
# Implement your chosen strategy to handle the null values. You can use the fillna() function in pandas to fill null values or dropna() function to drop null values.
#
# Verify that your strategy has successfully handled the null values. You can use the isnull() function again to check if there are still null values in the dataset.
#
# Remember to document your process and explain your reasoning for choosing a particular strategy for handling null values.

# %% [markdown]
# After formatting data types, as a last step, convert all the numeric variables to integers using applymap.

# %% [markdown]
# Save the cleaned dataset to a new CSV file.

# %%
customer.isna().sum()
# Out:
# customer                     2937
# state                        2937
# gender                       3054
# education                    2937
# customer_lifetime_value      2940
# income                       2937
# monthly_premium_auto         2937
# number_of_open_complaints    2937
# policy_type                  2937
# vehicle_class                2937
# total_claim_amount           2937
# dtype: int64

# %%
#drop completely empty rows and make sure it sticks in the df
customer.dropna(axis = 0, how = 'all', inplace = True)

# %%
# check remaining nans
customer.isna().sum()
# Out:
# customer                       0
# state                          0
# gender                       117
# education                      0
# customer_lifetime_value        3
# income                         0
# monthly_premium_auto           0
# number_of_open_complaints      0
# policy_type                    0
# vehicle_class                  0
# total_claim_amount             0
# dtype: int64

# %%
# count values including nans to check highest value
customer['gender'].value_counts(dropna=False)

# replace 117 nans with most common value
customer['gender'] = customer['gender'].fillna('F')
customer['gender'].value_counts()
# Out:
# F    619
# M    452
# Name: gender, dtype: int64

# %%
#replace 3 nans with zero
customer['customer_lifetime_value'] = customer['customer_lifetime_value'].fillna(0)

# %%
customer.isna().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# policy_type                  0
# vehicle_class                0
# total_claim_amount           0
# dtype: int64

# %% [markdown]
# ## Exercise 5: Dealing with duplicates

# %% [markdown]
# Use the .duplicated() method to identify any duplicate rows in the dataframe.
#
# Decide on a strategy for handling the duplicates. Options include:
# - Dropping all duplicate rows
# - Keeping only the first occurrence of each duplicated row
# - Keeping only the last occurrence of each duplicated row
# - Dropping duplicates based on a subset of columns
# - Dropping duplicates based on a specific column
#
# Implement your chosen strategy using the drop_duplicates() function.
#
# Verify that your strategy has successfully handled the duplicates by checking for duplicates again using .duplicated().
#
# Remember to document your process and explain your reasoning for choosing a particular strategy for handling duplicates.
#
# Save the cleaned dataset to a new CSV file.

# %%
duplicates = customer[customer.duplicated()] #select duplicate rows except first occurrence based on all columns
duplicates
# Out:
# Empty DataFrame
# Columns: [customer, state, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, policy_type, vehicle_class, total_claim_amount]
# Index: []

# %%
customer.to_csv()
# Out:
# ',customer,state,gender,education,customer_lifetime_value,income,monthly_premium_auto,number_of_open_complaints,policy_type,vehicle_class,total_claim_amount\n0,RB50392,Washington,F,Master,0.0,0.0,1000.0,0,Personal Auto,Four-Door Car,2.704934\n1,QZ44356,Arizona,F,Bachelor,6979.5359,0.0,94.0,0,Personal Auto,Four-Door Car,1131.464935\n2,AI49188,Nevada,F,Bachelor,12887.4317,48767.0,108.0,0,Personal Auto,Two-Door Car,566.472247\n3,WW63253,California,M,Bachelor,7645.861800000001,0.0,106.0,0,Corporate Auto,SUV,529.881344\n4,GA49547,Washington,M,High School or Below,5363.0765,36357.0,68.0,0,Personal Auto,Four-Door Car,17.269323\n5,OC83172,Oregon,F,Bachelor,8256.2978,62902.0,69.0,0,Personal Auto,Two-Door Car,159.383042\n6,XZ87318,Oregon,F,College,5380.8985999999995,55350.0,67.0,0,Corporate Auto,Four-Door Car,321.6\n7,CF85061,Arizona,M,Master,7216.1003,0.0,101.0,0,Corporate Auto,Four-Door Car,363.02968\n8,DY87989,Oregon,M,Bachelor,24127.504,14072.0,71.0,0,Corporate Auto,Four-Door Car,511.2\n9,BQ94931,Oregon,F,College,7388.178100000001,28812.0,93.0,0,Special Auto,Four-Door Car,425.527834\n10,SX51350,California,M,College,4738.992,0.0,67.0,0,Personal Auto,Four-Door Car,482.4\n11,VQ65197,California,F,College,8197.1971,0.0,110.0,0,Personal Auto,SUV,528.0\n12,DP39365,California,F,Master,8798.796999999999,77026.0,110.0,2,Corporate Auto,Four-Door Car,472.029737\n13,SJ95423,Arizona,F,High School or Below,8819.018900000001,99845.0,110.0,1,Corporate Auto,SUV,528.0\n14,IL66569,California,F,College,5384.4317,83689.0,70.0,2,Corporate Auto,Four-Door Car,307.139132\n15,BW63560,Oregon,F,Bachelor,7463.139399999999,24599.0,64.0,1,Corporate Auto,Four-Door Car,42.920271\n16,FV94802,Nevada,F,High School or Below,2566.8678,25049.0,67.0,0,Personal Auto,Two-Door Car,454.245098\n17,OE15005,California,F,College,3945.2416,28855.0,101.0,0,Personal Auto,SUV,647.442031\n18,WC83389,Oregon,F,College,5710.333100000001,51148.0,72.0,0,Personal Auto,Four-Door Car,308.981664\n19,FL50705,California,F,High School or Below,8162.6170999999995,66140.0,101.0,0,Corporate Auto,Four-Door Car,484.8\n20,ZK25313,Oregon,F,High School or Below,2872.0513,57749.0,74.0,0,Personal Auto,Two-Door Car,355.2\n21,QK46697,Washington,M,Bachelors,6177.1093,61040.0,79.0,1,Personal Auto,Two-Door Car,20.382876\n22,YH23384,Arizona,F,Bachelor,24127.504,14072.0,71.0,0,Personal Auto,Four-Door Car,511.2\n23,TZ98966,Nevada,F,Bachelor,2450.1910000000003,0.0,73.0,3,Corporate Auto,Four-Door Car,554.376763\n24,HM55802,California,F,Bachelor,2392.1079,17870.0,61.0,0,Corporate Auto,Four-Door Car,439.2\n25,FS42516,Oregon,F,College,5802.066,97541.0,72.0,0,Personal Auto,Four-Door Car,389.185006\n26,US89481,California,F,Bachelor,3946.3721,0.0,111.0,0,Personal Auto,Four-Door Car,799.2\n27,HS14476,Washington,M,College,9162.063199999999,29723.0,80.0,0,Personal Auto,Four-Door Car,20.985105\n28,GE62437,Arizona,F,College,12902.5601,86584.0,111.0,2,Personal Auto,Four-Door Car,532.8\n29,EJ77678,Oregon,F,Master,3235.3605,75690.0,80.0,1,Personal Auto,Four-Door Car,384.0\n30,SV85652,Arizona,F,College,2454.5835,23158.0,63.0,1,Personal Auto,Four-Door Car,322.294043\n31,UL64533,Nevada,F,High School or Below,18975.4561,65999.0,237.0,0,Corporate Auto,Luxury SUV,615.927769\n32,PF41800,California,F,Bachelor,4715.3213,0.0,65.0,0,Personal Auto,Four-Door Car,308.15089\n33,HD95276,Washington,F,College,4737.8717,0.0,130.0,0,Personal Auto,SUV,23.820158\n34,SK67821,Oregon,F,Bachelor,4932.9163,37260.0,62.0,0,Corporate Auto,Four-Door Car,15.437681\n35,YV55495,Arizona,F,High School or Below,5744.2297,68987.0,71.0,0,Personal Auto,Four-Door Car,204.475147\n36,KY38074,California,F,Bachelor,13891.735700000001,42305.0,117.0,0,Personal Auto,Four-Door Car,561.6\n37,DM79012,Oregon,F,Master,7380.9767,65706.0,91.0,0,Personal Auto,Four-Door Car,436.8\n38,CM61827,Oregon,F,Bachelor,3090.0341,0.0,90.0,0,Personal Auto,Two-Door Car,648.0\n39,WC35801,Arizona,F,High School or Below,2521.6331,53243.0,66.0,2,Personal Auto,Four-Door Car,157.397849\n40,QG25316,Nevada, ...

# %% [markdown]
# # Challenge 2: creating functions on a separate `py` file

# %% [markdown]
# Put all the data cleaning and formatting steps into functions, and create a main function that performs all the cleaning and formatting.
#
# Write these functions in a separate .py file(s). By putting these steps into functions, we can make the code more modular and easier to maintain.

# %% [markdown]
# *Hint: autoreload module is a utility module in Python that allows you to automatically reload modules in the current session when changes are made to the source code. This can be useful in situations where you are actively developing code and want to see the effects of changes you make without having to constantly restart the Python interpreter or Jupyter Notebook kernel.*

# %%
# turn column headers into snake_case
def column_snake_case(x):
    return x.columns.str.lower().str.replace(' ','_')

# make percentage objs into floats for manipulation
def percentage_to_float(x):
    return x = x.str.rstrip('%').astype('float')

# clean and format genders
def clean_gender(x):
    if x.startswith('M'):
        return 'M'
    elif x.startswith('F') :
        return 'F'

# %% [markdown]
# # Challenge 3: Analyzing Clean and Formated Data

# %% [markdown]
# You have been tasked with analyzing the data to identify potential areas for improving customer retention and profitability. Your goal is to identify customers with a high policy claim amount and a low customer lifetime value.
#
# In Pandas Lab, we only looked at high policy claim amounts because we couldn't look into low customer lifetime values. If we tried to do work with that column, we wouldn't have been able to do it because customer lifetime value wasn't clean and in its proper format. So after cleaning and formatting the data, lets get some more interesting insights!
#
# Instructions:
#
# - Review again the statistics for total claim amount and customer lifetime value to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount and a low customer lifetime value. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount, and clients with a low customer lifetime value to be those in the bottom 25% of the customer lifetime value. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile and a customer lifetime value in the bottom 25th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount and low customer lifetime value data. To do so, select both columns of the dataframe simultaneously and pass it to the .describe() method. This will give you descriptive statistics, such as mean, median, standard deviation, minimum and maximum values for both columns at the same time, allowing you to compare and analyze their characteristics.

# %%
top_25 = float(customer['total_claim_amount'].quantile(q = [0.75]))
top_25

bottom_25 = float(customer['customer_lifetime_value'].quantile(q = [0.25]))
bottom_25
# Out:
# 4019.7527499999997

# %%
potentials = customer.copy()
top_customers = potentials[(potentials['total_claim_amount'] > top_25) & (potentials['customer_lifetime_value'] < bottom_25)]
# have it show whoever falls in top 25 in one and bottom 25 of the other

top_customers.index = range(len(top_customers.index)) # reset the indexes to reflect new dataframe
top_customers
# Out:
#    customer       state gender             education  customer_lifetime_value  \
# 0   OE15005  California      F               College                3945.2416
# 1   TZ98966      Nevada      F              Bachelor                2450.1910
# 2   US89481  California      F              Bachelor                3946.3721
# 3   CM61827      Oregon      F              Bachelor                3090.0341
# 4   IL19217  California      F              Bachelor                3939.0064
# 5   FG63582      Oregon      F              Bachelor                3339.7649
# 6   DS81757      Oregon      M               College                2470.1212
# 7   KA61892     Arizona      M               College                3873.6470
# 8   ND87334  California      M  High School or Below                2287.5969
# 9   TS19868  California      M               College                2413.1397
# 10  AB13432  California      M              Bachelor                3735.8381
# 11  FL34139  California      M  High School or Below                3688.1109
# 12  IA63417     Arizona      F  High School or Below                4001.5191
# 13  VZ51506     Arizona      F  High School or Below                3595.3129
# 14  OH60605      Oregon      F  High School or Below                3652.5324
# 15  RR77985      Oregon      F              Bachelor                2887.7423
# 16  JF36291  California      M               College                3873.6470
# 17  ZF84449      Oregon      F               College                3726.7280
# 18  NL93182      Nevada      M              Bachelor                2549.4500
# 19  WE68644      Oregon      F              Bachelor                3803.9218
# 20  AU96286      Oregon      F              Bachelor                3167.6584
# 21  FY51713     Arizona      F              Bachelor                3570.7605
# 22  XN11823      Nevada      F              Bachelor                3764.4651
# 23  PX17116      Nevada      M               College                3623.4542
# 24  XS12556  California      F               College                3683.0999
# 25  UK41984     Arizona      F                Doctor                3839.6061
# 26  ZK21724      Oregon      F  High School or Below                4016.5420
# 27  DM95829  California      M               College                2523.9596
# 28  JA41698      Nevada      M              Bachelor                3099.5380
# 29  ED50963  California      F  High School or Below                2688.8640
# 30  TE13577      Oregon      F               College                2319.7359
# 31  TV25678  Washington      M               College                3540.9043
# 32  KJ87930  California      F              Bachelor                3886.5048
# 33  XM72420     Arizona      F  High School or Below                3919.3667
# 34  TD10493      Oregon      F  High School or Below                2898.7327
# 35  OT52034  California      M              Bachelor                3864.7768
# 36  UI73201  California      M               College                3667.3750
# 37  GS98873     Arizona      F              Bachelor                3239.1247
#
#      income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0   28855.0                 101.0                         0   Personal Auto
# 1       0.0                  73.0                         3  Corporate Auto
# 2       0.0                 111.0                         0   Personal Auto
# 3       0.0                  90.0                         0   Personal Auto
# 4   60021.0                  99.0                         0   Personal Auto
# 5       0.0                  94.0                         0   Personal Auto
# 6       0.0                  74.0                         0   Personal Auto
# 7   28142.0                 105.0                         0   Personal Auto
# 8       0.0                  63.0                         0  Corporate Auto
# 9   27501.0                  63.0                         0   Personal Auto
# 10      0.0                 110.0                         0   Personal Auto
# 11      0.0                  63.0                         3   Personal Auto
# 12  19782.0                 108.0                         0   Personal Auto
# 13      0.0                 103.0                         0  Corporate Auto
# 14  39679.0                  92.0                         0   Personal Auto
# 15      0.0                  80.0                         0   Personal Auto
# 16  28142.0                 105.0                         0   Personal Auto
# 17      0.0                 112.0                         1    Special Auto
# 18      0.0                  78.0                         0  Corporate Auto
# 19  20325.0                 100.0                         0   Personal Auto
# 20      0.0                  92.0                         0  Corporate Auto
# 21  56168.0                  88.0                         0   Personal Auto
# 22  92600.0                  94.0                         0  Corporate Auto
# 23      0.0                 111.0                         2  Corporate Auto
# 24      0.0                 101.0                         0  Corporate Auto
# 25      0.0                 112.0                         2   Personal Auto
# 26      0.0                 111.0                         0   Personal Auto
# 27  16244.0                  68.0                         0   Personal Auto
# 28      0.0                 102.0                         5  Corporate Auto
# 29  32808.0                  68.0                         1   Personal Auto
# 30      0.0                  64.0                         0   Personal Auto
# 31      0.0                 101.0                         0   Personal Auto
# 32      0.0                 112.0                         0  Corporate Auto
# 33  66676.0                  97.0                         0   Personal Auto
# 34      0.0                  96.0                         4   Personal Auto
# 35  24204.0                  99.0                         1   Personal Auto
# 36  62375.0                  92.0                         0   Personal Auto
# 37  16061.0                  88.0                         0   Personal Auto
#
#     vehicle_class  total_claim_amount
# 0             SUV          647.442031
# 1   Four-Door Car          554.376763
# 2   Four-Door Car          799.200000
# 3    Two-Door Car          648.000000
# 4   Four-Door Car          882.871945
# 5    Two-Door Car          863.327324
# 6    Two-Door Car          721.242206
# 7      Sports Car          701.708239
# 8    Two-Door Car          679.368378
# 9   Four-Door Car          542.319401
# 10            SUV          792.000000
# 11  Four-Door Car          669.682001
# 12   Two-Door Car          773.470977
# 13     Sports Car          741.600000
# 14   Two-Door Car          641.388616
# 15  Four-Door Car          676.944023
# 16     Sports Car          701.708239
# 17     Sports Car          806.400000
# 18  Four-Door Car          845.654042
# 19     Sports Car          668.293970
# 20  Four-Door Car          662.400000
# 21  Four-Door Car          614.675906
# 22   Two-Door Car          842.437850
# 23            SUV         1171.931170
# 24     Sports Car          564.466556
# 25            SUV          537.600000
# 26            SUV          799.200000
# 27   Two-Door Car          623.223617
# 28            SUV          862.762957
# 29  Four-Door Car          541.695658
# 30  Four-Door Car          632.715382
# 31            SUV          727.200000
# 32            SUV         1185.988301
# 33  Four-Door Car          558.099357
# 34  Four-Door Car          691.200000
# 35  Four-Door Car          707.303416
# 36   Two-Door Car          618.630955
# 37  Four-Door Car          633.600000

# %%
#describe 2 columns
customer[['total_claim_amount','customer_lifetime_value']].describe()
# Out:
#        total_claim_amount  customer_lifetime_value
# count         1071.000000              1071.000000
# mean           404.986909              7914.670373
# std            293.027260              6439.447084
# min              0.382107                 0.000000
# 25%            202.157702              4019.752750
# 50%            354.729129              5849.321500
# 75%            532.800000              8945.209950
# max           2893.239678             58166.553500
